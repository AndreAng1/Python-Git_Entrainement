# %%
import pandas as pd
import matplotlib

# %matplotlib inline

# %%
df= pd.read_csv("http://www.xavierdupre.fr/enseignement/complements/donnees_enquete_2003_television.txt",sep="\t")
df.head()
# Out:
#     POIDLOG        POIDSF  cLT1FREQ  cLT2FREQ  Unnamed: 4  Unnamed: 5  \
# 0  0.889422   4766.865201         2       1.0         NaN         NaN
# 1  2.310209  12381.589746        30       1.0         NaN         NaN
# 2  2.740070  14685.431344         6       2.0         NaN         NaN
# 3  1.775545   9516.049939         1       1.0         NaN         NaN
# 4  0.732512   3925.907588         3       1.0         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 22  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1         NaN         NaN         NaN         NaN  ...          NaN
# 2         NaN         NaN         NaN         NaN  ...          NaN
# 3         NaN         NaN         NaN         NaN  ...          NaN
# 4         NaN         NaN         NaN         NaN  ...          NaN
#
#    Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  \
# ...

# %%
cols_vides=[col for col in df.columns if df[col].isnull().all()]       #on supprime les colonnes vides 
df.drop (cols_vides,
        axis=1,
        inplace=True)

# %%
df
# Out:
#        POIDLOG        POIDSF  cLT1FREQ  cLT2FREQ
# 0     0.889422   4766.865201         2       1.0
# 1     2.310209  12381.589746        30       1.0
# 2     2.740070  14685.431344         6       2.0
# 3     1.775545   9516.049939         1       1.0
# 4     0.732512   3925.907588         3       1.0
# ...        ...           ...       ...       ...
# 8398  0.306852   1644.574141         6       1.0
# 8399  2.501181  13405.104689         6       1.0
# 8400  1.382758   7410.905653         1       1.0
# 8401  0.343340   1840.132652         3       1.0
# 8402  1.088486   5833.750895         0       NaN
#
# [8403 rows x 4 columns]

# %%
df.head()     # afficher les 5 premières lignes
# Out:
#     POIDLOG        POIDSF  cLT1FREQ  cLT2FREQ
# 0  0.889422   4766.865201         2       1.0
# 1  2.310209  12381.589746        30       1.0
# 2  2.740070  14685.431344         6       2.0
# 3  1.775545   9516.049939         1       1.0
# 4  0.732512   3925.907588         3       1.0

# %%
df.tail()  # afficher les 5 dernièeres lignes du df
# Out:
#        POIDLOG        POIDSF  cLT1FREQ  cLT2FREQ
# 8398  0.306852   1644.574141         6       1.0
# 8399  2.501181  13405.104689         6       1.0
# 8400  1.382758   7410.905653         1       1.0
# 8401  0.343340   1840.132652         3       1.0
# 8402  1.088486   5833.750895         0       NaN

# %%
df.shape  # pour savoir directement le nombre de ligne et de colonnes
# Out:
# (8403, 4)

# %%
df['cLT1FREQ'].mean()   # calculer la moyenne de la colonne seconde, on aurait pu mettre la colonne seconde dans une variable et faire la moyenne sur cette variable
# Out:
# 2.9302630013090565

# %%
df['cLT1FREQ'].describe()   #describe pour avoir toute les variables statistiques de cette colonne
# Out:
# count    8403.000000
# mean        2.930263
# std         2.958877
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max        50.000000
# Name: cLT1FREQ, dtype: float64

# %%
df['ville'].value_counts() #pour les variables non numérique, afin d'avoir le nombre de fois qu'on a une telle ville

# %%
df[['cLT1FREQ','POIDLOG']]  #avoir une matrice juste avec "cLT1FREQ et POIDSLOG". idem, on peut mettre ça dans une variable: x=df[['cLT1FREQ','POIDLOG']]

# %%
#  df.plot

# %%
#  x=df.plot(kind = "bar", figsize=(14,6))

# %%
# x

# %%
df.iloc [4] #pour choisir la ligne 4, le i de iloc c'est pour index
# Out:
# POIDLOG        0.732512
# POIDSF      3925.907588
# cLT1FREQ       3.000000
# cLT2FREQ       1.000000
# Name: 4, dtype: float64

# %%
df.iloc[4:10]  #pour choisir un ensemble de lignes
# Out:
#     POIDLOG       POIDSF  cLT1FREQ  cLT2FREQ
# 4  0.732512  3925.907588         3       1.0
# 5  1.758334  9423.810705         3       1.0
# 6  1.640733  8793.525107         3       1.0
# 7  0.413979  2218.723996         0       NaN
# 8  1.379033  7390.941189         1       1.0
# 9  0.764835  4099.142423         1       1.0

# %%
df.iloc[4:10, [2]]  #pour choisir un ensemble de lignes et n'afficher que la colonne sélectionnée. Colonne 2= cLT1FREQ car on compte 0 1 2 3 4 .... et c'est la 3eme colonne
# Out:
#    cLT1FREQ
# 4         3
# 5         3
# 6         3
# 7         0
# 8         1
# 9         1

# %%
df.iloc[4:10, [0,2]] #on choisit 2 colonnes pour les index sélectionnés
# Out:
#     POIDLOG  cLT1FREQ
# 4  0.732512         3
# 5  1.758334         3
# 6  1.640733         3
# 7  0.413979         0
# 8  1.379033         1
# 9  0.764835         1

# %%
#utilisation du loc, pour choisir les colonnes, le loc fonctionne en mode label, on met le nom

df.loc[4:10,['POIDLOG','cLT1FREQ']] #même chose que la ligne du déssus, sauf qu'à la place des chiffres pour les colonnes on met le noms de celles-ci
# Out:
#      POIDLOG  cLT1FREQ
# 4   0.732512         3
# 5   1.758334         3
# 6   1.640733         3
# 7   0.413979         0
# 8   1.379033         1
# 9   0.764835         1
# 10  0.833731         0

# %%
#filtre 
cLT1FREQ_filtre=(df['cLT1FREQ']==3)   # n'afficher que les lignes avec cLT1FREQ=3

# %%
df[cLT1FREQ_filtre]
# Out:
#        POIDLOG       POIDSF  cLT1FREQ  cLT2FREQ
# 4     0.732512  3925.907588         3       1.0
# 5     1.758334  9423.810705         3       1.0
# 6     1.640733  8793.525107         3       1.0
# 12    1.414299  7579.948801         3       1.0
# 15    0.931974  4994.923792         3       1.0
# ...        ...          ...       ...       ...
# 8392  1.088486  5833.750895         3       1.0
# 8394  1.115584  5978.981867         3       1.0
# 8395  0.340379  1824.264028         3       1.0
# 8397  0.502091  2690.961176         3       1.0
# 8401  0.343340  1840.132652         3       1.0
#
# [1775 rows x 4 columns]

# %%
#si on veut juste les POIDLOG des cLT1FREQ=3
df.loc[cLT1FREQ_filtre,'POIDLOG']
# Out:
# 4       0.732512
# 5       1.758334
# 6       1.640733
# 12      1.414299
# 15      0.931974
#           ...
# 8392    1.088486
# 8394    1.115584
# 8395    0.340379
# 8397    0.502091
# 8401    0.343340
# Name: POIDLOG, Length: 1775, dtype: float64

# %%
#afficher les POIDLOG des cLT1FREQ=3 qui ont un POIDSF<3925.907588
cLT1FREQ_filtre_bis=((df['cLT1FREQ']==3)& (df['POIDSF']<3925.907588))
df.loc[cLT1FREQ_filtre_bis,'POIDLOG']
# Out:
# 40      0.697689
# 41      0.497466
# 83      0.613901
# 186     0.715873
# 192     0.497849
#           ...
# 8374    0.515562
# 8379    0.397019
# 8395    0.340379
# 8397    0.502091
# 8401    0.343340
# Name: POIDLOG, Length: 777, dtype: float64

# %%
cLT1FREQ_filtre_bis=((df['cLT1FREQ']==3)& (df['POIDSF']<3925.907588))
df.loc[cLT1FREQ_filtre_bis,['POIDLOG','cLT1FREQ']]  #si on veu afficher d'autres variables
# Out:
#        POIDLOG  cLT1FREQ
# 40    0.697689         3
# 41    0.497466         3
# 83    0.613901         3
# 186   0.715873         3
# 192   0.497849         3
# ...        ...       ...
# 8374  0.515562         3
# 8379  0.397019         3
# 8395  0.340379         3
# 8397  0.502091         3
# 8401  0.343340         3
#
# [777 rows x 2 columns]

# %%
g= df.groupby('cLT1FREQ')

# %%
g

# %%
for cLT1FREQ, cLT1FREQ_df in g:
    print (cLT1FREQ)
    print(cLT1FREQ_df)
# Out:
# 0
#        POIDLOG        POIDSF  cLT1FREQ  cLT2FREQ
# 7     0.413979   2218.723996         0       NaN
# 10    0.833731   4468.391085         0       NaN
# 13    0.831108   4454.331802         0       NaN
# 24    0.460401   2467.522690         0       NaN
# 25    0.386721   2072.635959         0       NaN
# ...        ...           ...       ...       ...
# 8372  2.015588  10802.565294         0       NaN
# 8376  1.441587   7726.197586         0       NaN
# 8378  0.566105   3034.043534         0       NaN
# 8384  1.828638   9800.605535         0       NaN
# 8402  1.088486   5833.750895         0       NaN
#
# [1017 rows x 4 columns]
# 1
#        POIDLOG       POIDSF  cLT1FREQ  cLT2FREQ
# 3     1.775545  9516.049939         1       1.0
# 8     1.379033  7390.941189         1       1.0
# 9     0.764835  4099.142423         1       1.0
# 17    0.907880  4865.790932         1       1.0
# 19    1.164694  6242.188616         1       1.0
# ...        ...          ...       ...       ...
# ...
